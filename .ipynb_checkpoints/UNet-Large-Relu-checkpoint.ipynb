# %%
# 1. Import required modules/libraries
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Precision, Recall
from segmentation_models.metrics import IOUScore
# Out:
# 2024-12-16 07:36:54.710939: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-16 07:36:54.718640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-16 07:36:54.726410: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-16 07:36:54.728960: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-16 07:36:54.735693: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-16 07:36:55.150680: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Segmentation Models: using `tf.keras` framework.

# %%
# 2. Define Metrics
# Pixel Accuracy
def pixel_accuracy(y_true, y_pred):
    y_pred_binary = tf.round(y_pred)  # Convert logits to binary
    return tf.reduce_mean(tf.cast(tf.equal(y_true, y_pred_binary), tf.float32))

# Dice Coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-7) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1e-7)

# Initialize Precision and Recall as Keras metrics globally
precision_metric = Precision()
recall_metric = Recall()

def f1_score(y_true, y_pred):
    precision_value = precision_metric(y_true, y_pred)
    recall_value = recall_metric(y_true, y_pred)
    f1 = 2 * (precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon())
    return f1
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734323815.930301   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323815.957129   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323815.957164   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323815.961500   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323815.961527   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323815.961538   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323816.183517   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734323816.183558   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-16 07:36:56.183565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1734323816.183587   17726 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-16 07:36:56.183600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 3. Function to load images and labels
def load_images_and_labels(image_dir, label_dir, image_size=(288, 288)):
    images = []
    labels = []
    
    for image_name in sorted(os.listdir(image_dir)):
        # Load image and label
        img_path = os.path.join(image_dir, image_name)
        label_path = os.path.join(label_dir, image_name)
        
        image = img_to_array(load_img(img_path, target_size=image_size, color_mode='grayscale')) / 255.0
        label = img_to_array(load_img(label_path, target_size=image_size, color_mode='grayscale')) / 255.0
        
        images.append(image)
        labels.append(label)
        
    return np.array(images), np.array(labels)

# %%
# 4. Load datasets
train_images_dir = "data/train/image/"
train_labels_dir = "data/train/label/"

val_images_dir = "data/val/image/"
val_labels_dir = "data/val/label/"

test_images_dir = "data/test/image/"
test_labels_dir = "data/test/label/"

final_test_images_dir = "data/final_test/image/"
final_test_labels_dir = "data/final_test/label/"

train_images, train_labels = load_images_and_labels(train_images_dir, train_labels_dir)
val_images, val_labels = load_images_and_labels(val_images_dir, val_labels_dir)
test_images, test_labels = load_images_and_labels(test_images_dir, test_labels_dir)

# %%
# 5. Define U-Net model
def unet_model(input_size=(288, 288, 1)):
    inputs = Input(input_size)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)    

    # Bottleneck
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u1 = UpSampling2D((2, 2))(c5)
    c6 = concatenate([u1, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u2 = UpSampling2D((2, 2))(c6)
    c7 = concatenate([u2, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u3 = UpSampling2D((2, 2))(c7)
    c8 = concatenate([u3, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u4 = UpSampling2D((2, 2))(c8)
    c9 = concatenate([u4, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)
    
    outputs = Conv2D(1, (1, 1), activation='relu')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Initialize model
model = unet_model()

# %%
# 6. Compile the model
model.compile(
    optimizer='adam',
    loss=BinaryCrossentropy(),  
    metrics=[
        IOUScore(name='iou_score'), 
        pixel_accuracy, 
        dice_coefficient, 
        precision_metric, 
        recall_metric, 
        f1_score  
    ]
)

# %%
# 7. Print model summary
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 288, 288,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 288, 288,  │        640 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 288, 288,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 144, 144,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 144, 144,  │     73,856 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 144, 144,  │    147,584 │ conv2d_2[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 72, 72,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 72, 72,    │    295,168 │ max_pooling2d_1[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 72, 72,    │    590,080 │ conv2d_4[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 36, 36,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 36, 36,    │  1,180,160 │ max_pooling2d_2[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 36, 36,    │  2,359,808 │ conv2d_6[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 18, 18,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 18, 18,    │  4,719,616 │ max_pooling2d_3[… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 18, 18,    │  9,438,208 │ conv2d_8[0][0]    │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 36, 36,    │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 36, 36,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1536)             │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 36, 36,    │  7,078,400 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 36, 36,    │  2,359,808 │ conv2d_10[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 72, 72,    │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 72, 72,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 768)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 72, 72,    │  1,769,728 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 72, 72,    │    590,080 │ conv2d_12[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 144, 144,  │          0 │ conv2d_13[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 144, 144,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 384)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 144, 144,  │    442,496 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 144, 144,  │    147,584 │ conv2d_14[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 288, 288,  │          0 │ conv2d_15[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 288, 288,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 288, 288,  │    110,656 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 288, 288,  │     36,928 │ conv2d_16[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 288, 288,  │         65 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 31,377,793 (119.70 MB)
#  Trainable params: 31,377,793 (119.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 8. Train the model
history = model.fit(
    train_images, train_labels,
    validation_data=(val_images, val_labels),
    batch_size=16,
    epochs=50
)
# Out:
# Epoch 1/50
# /home/skye/tf/lib/python3.11/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734323820.719041   17874 service.cc:146] XLA service 0x7f992c01a850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734323820.719647   17874 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-12-16 07:37:00.801781: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-16 07:37:01.067023: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-12-16 07:37:14.440765: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.80GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:15.118891: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.47GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:16.272687: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.36GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1734323839.392236   17874 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 39/42 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - dice_coefficient: 0.2052 - f1_score: 0.1835 - iou_score: 0.1188 - loss: 1.0510 - pixel_accuracy: 0.7630 - precision: 0.3868 - recall: 0.1274
# 2024-12-16 07:37:33.705629: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.79GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:34.040902: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.43GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:34.462887: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 24.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - dice_coefficient: 0.2070 - f1_score: 0.1834 - iou_score: 0.1191 - loss: 1.0416 - pixel_accuracy: 0.7635 - precision: 0.3890 - recall: 0.1269
# 2024-12-16 07:37:40.875320: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.57GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:41.451676: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:42.036291: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 27.23GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-16 07:37:45.413328: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 25.13GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 48s 658ms/step - dice_coefficient: 0.2076 - f1_score: 0.1833 - iou_score: 0.1195 - loss: 1.0326 - pixel_accuracy: 0.7641 - precision: 0.3912 - recall: 0.1264 - val_dice_coefficient: 0.2477 - val_f1_score: 0.1244 - val_iou_score: 0.1432 - val_loss: 0.2128 - val_pixel_accuracy: 0.7954 - val_precision: 0.9780 - val_recall: 0.0579
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - dice_coefficient: 0.2750 - f1_score: 0.1380 - iou_score: 0.1597 - loss: 0.2035 - pixel_accuracy: 0.8084 - precision: 0.9715 - recall: 0.0856 - val_dice_coefficient: 0.2886 - val_f1_score: 0.1944 - val_iou_score: 0.1714 - val_loss: 0.2058 - val_pixel_accuracy: 0.7982 - val_precision: 0.9784 - val_recall: 0.0966
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - dice_coefficient: 0
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - dice_coefficient: 0.3434 - f1_score: 0.1958 - iou_score: 0.2075 - loss: 0.1741 - pixel_accuracy: 0.8134 - precision: 0.9749 - recall: 0.1127 - val_dice_coefficient: 0.3622 - val_f1_score: 0.2719 - val_iou_score: 0.2234 - val_loss: 0.1815 - val_pixel_accuracy: 0.8003 - val_precision: 0.9832 - val_recall: 0.1433
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - dice_coefficient: 0.3402 - f1_score: 0.2156 - iou_score: 0.2055 - loss: 0.1763 - pixel_accuracy: 0.8112 - precision: 0.9802 - recall: 0.1155 - val_dice_coefficient: 0.3710 - val_f1_score: 0.2422 - val_iou_score: 0.2292 - val_loss: 0.1707 - val_pixel_accuracy: 0.8007 - val_precision: 0.9858 - val_recall: 0.1328
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - dice_coefficient: 0.3665 - f1_score: 0.2332 - iou_score: 0.2247 - loss: 0.1611 - pixel_accuracy: 0.8186 - precision: 0.9806 - recall: 0.1274 - val_dice_coefficient: 0.3554 - val_f1_score: 0.2068 - val_iou_score: 0.2182 - val_loss: 0.1773 - val_pixel_accuracy: 0.7985 - val_precision: 0.9842 - val_recall: 0.1028
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - dice_coefficient: 0.3598 - f1_score: 0.1984 - iou_score: 0.2196 - loss: 0.1617 - pixel_accuracy: 0.8180 - precision: 0.9733 - recall: 0.1174 - val_dice_coefficient: 0.3723 - val_f1_score: 0.2330 - val_iou_score: 0.2307 - val_loss: 0.1686 - val_pixel_accuracy: 0.8003 - val_precision: 0.9841 - val_recall: 0.1209
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 157ms/step - dice_coefficient: 0.3709 - f1_score: 0.2199 - iou_score: 0.2280 - loss: 0.1558 - pixel_accuracy: 0.8223 - precision: 0.9749 - recall: 0.1214 - val_dice_coefficient: 0.3658 - val_f1_score: 0.2161 - val_iou_score: 0.2252 - val_loss: 0.1690 - val_pixel_accuracy: 0.8003 - val_precision: 0.9852 - val_recall: 0.1133
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - dice_coefficient: 0.3561 - f1_score: 0.2085 - iou_score: 0.2169 - loss: 0.1690 - pixel_accuracy: 0.8143 - precision: 0.9819 - recall: 0.1231 - val_dice_coefficient: 0.3557 - val_f1_score: 0.1743 - val_iou_score: 0.2177 - val_loss: 0.1731 - val_pixel_accuracy: 0.7995 - val_precision: 0.9850 - val_recall: 0.0908
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - dice_coefficient: 0.3628 - f1_score: 0.1869 - iou_score: 0.2219 - loss: 0.1560 - pixel_accuracy: 0.8196 - precision: 0.9819 - recall: 0.1069 - val_dice_coefficient: 0.3974 - val_f1_score: 0.2587 - val_iou_score: 0.2495 - val_loss: 0.1646 - val_pixel_accuracy: 0.8022 - val_precision: 0.9862 - val_recall: 0.1493

# %%
# 9. Evaluate the model 
test_loss, test_iou, test_pixel_accuracy, test_dice, test_precision, test_recall, test_f1 = model.evaluate(
    test_images, test_labels,  batch_size=16
)

print(f"Test Loss: {test_loss}")
print(f"Test IoU: {test_iou}")
print(f"Test Pixel Accuracy: {test_pixel_accuracy}")
print(f"Test Dice Coefficient: {test_dice}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dice_coefficient: 0.4546 - f1_score: 0.3193 - iou_score: 0.2963 - loss: 0.1513 - pixel_accuracy: 0.8222 - precision: 0.9970 - recall: 0.1764
# Test Loss: 0.17635123431682587
# Test IoU: 0.2688594162464142
# Test Pixel Accuracy: 0.7977598309516907
# Test Dice Coefficient: 0.42022964358329773
# Test Precision: 0.9962373375892639
# Test Recall: 0.15612691640853882
# Test F1 Score: 0.3062412738800049

# %%
# 10. Save the model
model.save('Models/Unet_Large_Relu.keras')

# %%
# 11. Display results on test data
def display_results(test_images, test_labels, model):
    predictions = model.predict(test_images)
    for i in range(5):  # Display 5 examples
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 3, 1)
        plt.title("Test Image")
        plt.imshow(test_images[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(test_labels[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(predictions[i].squeeze(), cmap='gray')

        plt.show()

display_results(test_images, test_labels, model)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 16s 7s/step

# %%
# 12. Function to pad images 
def pad_image(image, target_size):
    pad_h = (target_size[0] - image.shape[0]) // 2
    pad_w = (target_size[1] - image.shape[1]) // 2
    
    padded_image = np.pad(image, ((pad_h, target_size[0] - image.shape[0] - pad_h),
                                  (pad_w, target_size[1] - image.shape[1] - pad_w),
                                  (0, 0)), mode='constant', constant_values=0)
    return padded_image

# %%
# 13.Function to display predictions on final test images
def display_final_results(final_test_images, final_test_labels, model, start, end):
    # Calculate the target size (next multiple of 16)
    target_size = ((1038 // 16 + 1) * 16, (1388 // 16 + 1) * 16)
    
    final_test_images_padded = np.array([pad_image(img, target_size) for img in final_test_images])
    final_predictions_padded = model.predict(final_test_images_padded[start:end])
    final_predictions = [pred[:1038, :1388, :] for pred in final_predictions_padded]
    x = 0

    for i in range(start, end):  
        plt.figure(figsize=(12, 4))
        print(i)

        plt.subplot(1, 3, 1)
        plt.title("Test Image")
        plt.imshow(final_test_images[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(final_test_labels[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(final_predictions[x].squeeze(), cmap='gray')
        x = x + 1
        
        plt.show()

# %%
# 14. Display results
final_test_images, final_test_labels = load_images_and_labels(final_test_images_dir, final_test_labels_dir, image_size=(1038, 1388))
# Predict results for a subgroup of the final test images as per memory capacity
display_final_results(final_test_images, final_test_labels, model, 0, 5)
# Out:
# E0000 00:00:1734324210.067155   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324210.178715   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324210.281771   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324211.634919   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324211.745758   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324226.974316   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734324227.133813   17868 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-12-16 07:43:49.882313: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[5,64,1040,1392]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,192,1040,1392]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-12-16 07:43:51.265293: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.383062335s
# Trying algorithm eng0{} for conv (f32[5,64,1040,1392]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,192,1040,1392]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 22s 22s/step
# 0
# 1
# 2
# 3
# 4

# %%
# Predict results for the remainder images
display_final_results(final_test_images, final_test_labels, model, 5, 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 5
# 6
# 7
# 8
# 9
