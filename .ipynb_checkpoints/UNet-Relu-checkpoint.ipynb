# %%
# 1. Import required modules/libraries
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import tensorflow as tf
# from segmentation_models.losses import DiceLoss
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Precision, Recall
from segmentation_models.metrics import IOUScore
# Out:
# 2024-12-14 23:28:34.887477: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-14 23:28:34.895276: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-14 23:28:34.904319: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-14 23:28:34.906805: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-14 23:28:34.913512: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-14 23:28:35.533989: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Segmentation Models: using `tf.keras` framework.

# %%
# Pixel Accuracy
def pixel_accuracy(y_true, y_pred):
    y_pred_binary = tf.round(y_pred)  # Convert logits to binary
    return tf.reduce_mean(tf.cast(tf.equal(y_true, y_pred_binary), tf.float32))

# Dice Coefficient
def dice_coefficient(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-7) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1e-7)

# Initialize Precision and Recall as Keras metrics globally
precision_metric = Precision()
recall_metric = Recall()

def f1_score(y_true, y_pred):
    precision_value = precision_metric(y_true, y_pred)
    recall_value = recall_metric(y_true, y_pred)
    f1 = 2 * (precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon())
    return f1
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734208116.429641    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.458579    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.458614    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.464244    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.464335    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.464409    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.569754    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1734208116.569821    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-14 23:28:36.569827: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1734208116.569850    7718 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-12-14 23:28:36.569864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21458 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# 2. Function to load images and labels
def load_images_and_labels(image_dir, label_dir, image_size=(288, 288)):
    images = []
    labels = []
    
    for image_name in sorted(os.listdir(image_dir)):
        # Load image and label
        img_path = os.path.join(image_dir, image_name)
        label_path = os.path.join(label_dir, image_name)
        
        image = img_to_array(load_img(img_path, target_size=image_size, color_mode='grayscale')) / 255.0
        label = img_to_array(load_img(label_path, target_size=image_size, color_mode='grayscale')) / 255.0
        
        images.append(image)
        labels.append(label)
        
    return np.array(images), np.array(labels)

# %%
# 3. Loading datasets
train_images_dir = "data/train/image/"
train_labels_dir = "data/train/label/"

val_images_dir = "data/val/image/"
val_labels_dir = "data/val/label/"

test_images_dir = "data/test/image/"
test_labels_dir = "data/test/label/"

final_test_images_dir = "data/final_test/image/"
final_test_labels_dir = "data/final_test/label/"

train_images, train_labels = load_images_and_labels(train_images_dir, train_labels_dir)
val_images, val_labels = load_images_and_labels(val_images_dir, val_labels_dir)
test_images, test_labels = load_images_and_labels(test_images_dir, test_labels_dir)

# %%
# 4. Define U-Net model
def unet_model(input_size=(288, 288, 1)):
    inputs = Input(input_size)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    # Bottleneck
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)

    # Decoder
    u1 = UpSampling2D((2, 2))(c4)
    c5 = concatenate([u1, c3])
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    u2 = UpSampling2D((2, 2))(c5)
    c6 = concatenate([u2, c2])
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u3 = UpSampling2D((2, 2))(c6)
    c7 = concatenate([u3, c1])
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Initialize model
model = unet_model()

# %%
# 5. Compile the model
# model.compile(optimizer=Adam(learning_rate=1e-4), 
#               loss=BinaryCrossentropy(), 
#               metrics=[MeanIoU(num_classes=2)])
# model.compile(optimizer=Adam(learning_rate=1e-4), loss=DiceLoss(), metrics=[MeanIoU(num_classes=2)])
# 2. Compile the model with the new metrics
model.compile(
    optimizer='adam',
    loss=BinaryCrossentropy(),  # Can be changed as needed
    metrics=[
        IOUScore(name='iou_score'), 
        pixel_accuracy, 
        dice_coefficient, 
        precision_metric, 
        recall_metric, 
        f1_score  # Ensure this is last as it depends on precision and recall
    ]
)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None,
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - dice_coefficient: 0.4075 - f1_score: 0.1711 - iou_score: 0.2563 - loss: 0.1420 - pixel_accuracy: 0.8200 - precision: 0.9887 - recall: 0.0977 - val_dice_coefficient: 0.4038 - val_f1_score: 0.1914 - val_iou_score: 0.2543 - val_loss: 0.1602 - val_pixel_accuracy: 0.8008 - val_precision: 0.9730 - val_recall: 0.1017
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - dice_coefficient: 0.4149 - f1_score: 0.1960 - iou_score: 0.2621 - loss: 0.1410 - pixel_accuracy: 0.8218 - precision: 0.9906 - recall: 0.1066 - val_dice_coefficient: 0.4042 - val_f1_score: 0.1845 - val_iou_score: 0.2547 - val_loss: 0.1592 - val_pixel_accuracy: 0.8010 - val_precision: 0.9746 - val_recall: 0.0993
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - dice_coefficient: 0.4174 - f1_score: 0.1935 - iou_score: 0.2641 - loss: 0.1376 - pixel_accuracy: 0.8239 - precision: 0.9923 - recall: 0.1061 - val_dice_coefficient: 0.4088 - val_f1_score: 0.1887 - val_iou_score: 0.2583 - val_loss: 0.1588 - val_pixel_accuracy: 0.8010 - val_precision: 0.9708 - val_recall: 0.1036
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - dice_coefficient: 0.4169 - f1_score: 0.1882 - iou_score: 0.2637 - loss: 0.1407 - pixel_accuracy: 0.8211 - precision: 0.9901 - recall: 0.1032 - val_dice_coefficient: 0.3960 - val_f1_score: 0.1679 - val_iou_score: 0.2484 - val_loss: 0.1604 - val_pixel_accuracy: 0.8001 - val_precision: 0.9797 - val_recall: 0.0895
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - dice_coefficient: 0.4168 - f1_score: 0.1836 - iou_score: 0.2637 - loss: 0.1443 - pixel_accuracy: 0.8152 - precision: 0.9964 - recall: 0.1018 - val_dice_coefficient: 0.3970 - val_f1_score: 0.1606 - val_iou_score: 0.2491 - val_loss: 0.1641 - val_pixel_accuracy: 0.8003 - val_precision: 0.9804 - val_recall: 0.0855
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - dice_coefficient: 0.4161 - f1_score: 0.1792 - iou_score: 0.2629 - loss: 0.1390 - pixel_accuracy: 0.8218 - precision: 0.9953 - recall: 0.1011 - val_dice_coefficient: 0.4050 - val_f1_score: 0.1904 - val_iou_score: 0.2552 - val_loss: 0.1593 - val_pixel_accuracy: 0.8012 - val_precision: 0.9755 - val_recall: 0.1042

# %%
# 7. Evaluate the model on test data
# results = model.evaluate(test_images, test_labels, batch_size=16)
# print("Test Loss, Test Mean IoU:", results)
# 4. Evaluate the model
test_loss, test_iou, test_pixel_accuracy, test_dice, test_precision, test_recall, test_f1 = model.evaluate(
    test_images, test_labels,  batch_size=16
)

print(f"Test Loss: {test_loss}")
print(f"Test IoU: {test_iou}")
print(f"Test Pixel Accuracy: {test_pixel_accuracy}")
print(f"Test Dice Coefficient: {test_dice}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - dice_coefficient: 0.4664 - f1_score: 0.2612 - iou_score: 0.3059 - loss: 0.1447 - pixel_accuracy: 0.8210 - precision: 0.9942 - recall: 0.1323
# Test Loss: 0.16687160730361938
# Test IoU: 0.27964550256729126
# Test Pixel Accuracy: 0.7965101599693298
# Test Dice Coefficient: 0.4342308044433594
# Test Precision: 0.9919605851173401
# Test Recall: 0.10960333049297333
# Test F1 Score: 0.2414226531982422

# %%
# 8. Display results on test data
def display_results(test_images, test_labels, model):
    predictions = model.predict(test_images)
    for i in range(5):  # Display 5 examples
        plt.figure(figsize=(12, 4))

        plt.subplot(1, 3, 1)
        plt.title("Test Image")
        plt.imshow(test_images[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(test_labels[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(predictions[i].squeeze(), cmap='gray')

        plt.show()

display_results(test_images, test_labels, model)
# Out:
# 2024-12-14 23:11:38.679520: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 27.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-14 23:11:39.175099: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 30.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 6s/step

# %%
# 9. Save the model
model.save("models/cell_nucleus_comet_model_unet.keras")

# %%
# 10. Test on larger final test images
def pad_image(image, target_size):
    pad_h = (target_size[0] - image.shape[0]) // 2
    pad_w = (target_size[1] - image.shape[1]) // 2
    
    padded_image = np.pad(image, ((pad_h, target_size[0] - image.shape[0] - pad_h),
                                  (pad_w, target_size[1] - image.shape[1] - pad_w),
                                  (0, 0)), mode='constant', constant_values=0)
    return padded_image

# %%
def display_final_results(final_test_images, final_test_labels, model, start, end):
    # Calculate the target size (next multiple of 16)
    target_size = ((1038 // 16 + 1) * 16, (1388 // 16 + 1) * 16)
    
    final_test_images_padded = np.array([pad_image(img, target_size) for img in final_test_images])
    final_predictions_padded = model.predict(final_test_images_padded[start:end])
    final_predictions = [pred[:1038, :1388, :] for pred in final_predictions_padded]
    x = 0

    # predictions = model.predict(test_images)
    for i in range(start, end):  # Display 5 examples
        plt.figure(figsize=(12, 4))
        print(i)

        plt.subplot(1, 3, 1)
        plt.title("Test Image")
        plt.imshow(final_test_images[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 2)
        plt.title("Ground Truth")
        plt.imshow(final_test_labels[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title("Prediction")
        plt.imshow(final_predictions[x].squeeze(), cmap='gray')
        x = x + 1
        
        plt.show()

# %%
# Calculate the target size (next multiple of 16)
# target_size = ((1038 // 16 + 1) * 16, (1388 // 16 + 1) * 16)

# Load and pad final test images
final_test_images, final_test_labels = load_images_and_labels(final_test_images_dir, final_test_labels_dir, image_size=(1038, 1388))
# final_test_images_padded = np.array([pad_image(img, target_size) for img in final_test_images])

# Predict on padded images
# final_predictions_padded = model.predict(final_test_images_padded[:3])

# Crop predictions back to original size
# final_predictions = [pred[:1038, :1388, :] for pred in final_predictions_padded]

# Display results
# for i, pred in enumerate(final_predictions):
#     plt.figure()
#     plt.title(f"Final Test Image {i+1} Prediction")
#     plt.imshow(pred.squeeze(), cmap='gray')
#     plt.show()

display_final_results(final_test_images, final_test_labels, model, 0, 5)
# Out:
# E0000 00:00:1734207108.383050    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734207108.485048    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734207109.969652    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734207110.080643    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734207121.267805    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1734207121.427611    3357 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2024-12-14 23:12:04.162117: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[5,64,1040,1392]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,192,1040,1392]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2024-12-14 23:12:05.532909: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 2.370879649s
# Trying algorithm eng0{} for conv (f32[5,64,1040,1392]{3,2,1,0}, u8[0]{0}) custom-call(f32[5,192,1040,1392]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step
# 0
# 1
# 2
# 3
# 4

# %%
display_final_results(final_test_images, final_test_labels, model, 5, 10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 5
# 6
# 7
# 8
# 9
